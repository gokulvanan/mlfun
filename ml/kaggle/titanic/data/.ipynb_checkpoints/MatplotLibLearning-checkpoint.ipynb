# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Simple example of giving only y values - x range defaults to index 0 to 3 in this case
plt.plot([1,2,3,4])
plt.ylabel("numbers")
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.ylabel("sqaures")
plt.xlabel("numbers")
plt.show()

# %%
#optional thrid arg can be used in plot function to change type of plot
plt.plot(x,y,"ro") #ro = red,dot .. default = b- which is blue line
plot.show()

# %%
#now above graph you can see for point 1 and 4 - the terminal as the axis boundry starts and ends at that
#to change axis of the graph
plt.plot(x,y,"ro")
plt.axis([0,6,0,20]) #range of x first then y
plt.show()

# %%
import numpy as np

data = np.arange(0.,5.,0.2) # similar to range o to 5 with step increment of 0.2
#plotting multiple plots
plt.plot(data,data,'r--',data,data**2,'bs', data,data**3,'g^')
plt.show()

# %%
#plt.plot(x,y,linewidth=10.0)  #change width of line in line plot
line, = plt.plot(x,y,"-") # plt.plot returns many attributes take the first one to set antialiased off
line.set_antialiased(False)

# %%
lines = plt.plot(2, 1, 3, 3)
# use keyword args
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# Out:
# [None, None, None, None]
